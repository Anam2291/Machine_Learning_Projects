# %% [markdown]
# #### Here "Classification"column is 'Diagnosis',use this model when the dataset is not too big,'Outlier'should be minimum,bcuz it look at outlier.

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('breast_cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.drop(columns=['id','Unnamed: 32'],inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# ##### We have to check 2 things in our model data,if there is 'imbalance data' it means one class has more values comparatively to other class

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (569, 31)

# %%
x =df.iloc[:,1:]
y =df.iloc[:,0]   #"Classification column is Diagnosis"

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state= 0)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 338       10.050         17.53           64.41      310.8          0.10070
# 427       10.800         21.98           68.79      359.9          0.08801
# 406       16.140         14.86          104.30      800.0          0.09495
# 96        12.180         17.84           77.79      451.1          0.10450
# 490       12.250         22.44           78.18      466.5          0.08192
# ..           ...           ...             ...        ...              ...
# 277       18.810         19.98          120.90     1102.0          0.08923
# 9         12.460         24.04           83.97      475.9          0.11860
# 359        9.436         18.32           59.82      278.6          0.10090
# 192        9.720         18.22           60.73      288.1          0.06950
# 559       11.510         23.93           74.52      403.5          0.09261
#
# ...

# %%
len(x_train)
# Out:
# 455

# %%
x_train.shape
# Out:
# (455, 30)

# %% [markdown]
# ##### When we see some columns i.e.area_mean,texture_mean,radius_mean they have bigger values remaining column values have 0.00 , 0.11,then we have to do scaling,so there is 2 types of scaling:-"Standard Scalar"and "MinMax Scalar"when dont know ranges(upper and lower) we apply standard scalar

# %%
from sklearn.preprocessing import StandardScaler
#'StandardScaler'take column mean & standard deviation
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-1.15036482, -0.39064196, -1.12855021, ..., -0.75798367,
#         -0.01614761, -0.38503402],
#        [-0.93798972,  0.68051405, -0.94820146, ..., -0.60687023,
#          0.09669004, -0.38615797],
#        [ 0.574121  , -1.03333557,  0.51394098, ..., -0.02371948,
#         -0.20050207, -0.75144254],
#        ...,
#        [-1.32422924, -0.20048168, -1.31754581, ..., -0.97974953,
#         -0.71542314, -0.11978123],
#        [-1.24380987, -0.2245526 , -1.28007609, ..., -1.75401433,
#         -1.58157125, -1.00601779],
#        [-0.73694129,  1.14989702, -0.71226578, ..., -0.27460457,
#         -1.25895095,  0.21515662]])

# %% [markdown]
# ### Model Selection

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3) #if putting bigger values,model will underfit

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [raw]
# from sklearn.metrics import accuracy_score
#
# y_pred = knn.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5789473684210527

# %%
from sklearn.metrics import accuracy_score
scores = []
for i in range(1,16):
    knn = KNeighborsClassifier(n_neighbors=i) 
    knn.fit(x_train,y_train)
    y_pred = knn.predict(x_test)
    scores.append(accuracy_score(y_test, y_pred))

# %%
scores
# Out:
# [0.9298245614035088,
#  0.9385964912280702,
#  0.9649122807017544,
#  0.9473684210526315,
#  0.9649122807017544,
#  0.956140350877193,
#  0.956140350877193,
#  0.956140350877193,
#  0.9473684210526315,
#  0.956140350877193,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.956140350877193,
#  0.956140350877193,
#  0.956140350877193]

# %%
np.argmax(scores)
# Out:
# 2

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,16),scores)
