# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('logistic_Regression.csv')
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
df.drop(columns=['User ID','Gender','EstimatedSalary'], inplace=True)
df.head(3)
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0

# %%
df.shape
# Out:
# (400, 2)

# %%
plt.figure(figsize=(3,3))
sns.scatterplot(x='Age',y='Purchased',data=df)
plt.show()

# %%
x = df[['Age']]
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train),len(x_test)
# Out:
# (320, 80)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train),lr.score(x_test,y_test)
# Out:
# (0.821875, 0.9125)

# %%
lr.predict([[60]])
# Out:
# C:\Users\anamn\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='Age',y='Purchased',data = df)
sns.lineplot(x='Age',y=lr.predict(x),data = df,color = 'red')
plt.show()
